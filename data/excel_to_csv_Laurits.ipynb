# %%
import pandas as pd

# %%
df = pd.read_excel('/Users/lauritsrichter/Desktop/ITU/projects in data science/Forked repo/2026-PDS-Q/data/annotations.xlsx')
df.describe()

df.image_name = df.image_name.str.replace(',', '')
df.head()
# Out:
#           image_name  hair  pen_marks
# 0  PAT_21_31_965.png     3          0
# 1  PAT_31_42_680.png     2          0
# 2   PAT_36_50_14.png     1          0
# 3  PAT_53_82_940.png     0          1
# 4  PAT_59_46_537.png     1          1

# %%
df.to_csv('annotations.csv')
